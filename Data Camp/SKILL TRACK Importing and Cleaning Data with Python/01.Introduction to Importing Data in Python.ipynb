# %%
def newprint():
    print('--------\n--------')
import os
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-793474f229db> in <module>
#       2     print('--------\n--------')
#       3 import os
# ----> 4 os.ls
#
# AttributeError: module 'os' has no attribute 'ls'

# %%
os.chdir('./data')

# %%
os.listdir()
# Out:
# ['airlines_final.csv',
#  'banking_dirty.csv',
#  'battledeath.xlsx',
#  'Chinook.sqlite',
#  'Data Science Courses_ R & Python Analysis Tutorials _ DataCamp.html',
#  'data.db',
#  'disarea.dta',
#  'fcc-new-coder-survey.xlsx',
#  'ja_data2.mat',
#  'L-L1_LOSC_4_V1-1126259446-32.hdf5',
#  'latitude.xls',
#  'mnist_kaggle_some_rows.csv',
#  'moby_dick.txt.txt',
#  'restaurants_L2.csv',
#  'restaurants_L2_dirty.csv',
#  'ride_sharing_new.csv',
#  'sales.sas7bdat',
#  'seaslug.txt',
#  'titanic_sub.csv',
#  'tweets3.txt',
#  'vt_tax_data_2016.csv',
#  'winequality-red.csv']

# %% [markdown]
# ### CH1: Introduction and flat files

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Open a file: file
file = open('moby_dick.txt' , mode='r')

# Print it
print(file.read())

newprint()
# Check whether file is closed
print(file.closed)

newprint()
# Close file

file.close()
# Check whether file is closed
print(file.closed)
# Out:
#  CHAPTER 1. Loomings.
#
#     Call me Ishmael. Some years ago--never mind how long precisely--having
#     little or no money in my purse, and nothing particular to interest me on
#     shore, I thought I would sail about a little and see the watery part of
#     the world. It is a way I have of driving off the spleen and regulating
#     the circulation. Whenever I find myself growing grim about the mouth;
#     whenever it is a damp, drizzly November in my soul; whenever I find
#     myself involuntarily pausing before coffin warehouses, and bringing up
#     the rear of every funeral I meet; and especially whenever my hypos get
#     such an upper hand of me, that it requires a strong moral principle to
#     prevent me from deliberately stepping into the street, and methodically
#     knocking people's hats off--then, I account it high time to get to sea
#     as soon as I can. This is my substitute for pistol and ball. With a
# ...
