# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import csv
import random
import threading as th

# %%
email = ""
password = ""

chromepath = "chromedriver.exe"

# %%
options = webdriver.ChromeOptions()

# options.add_argument("-disk-cache-size=3000000000")

driver = webdriver.Chrome(executable_path=chromepath)

driver.get("https://www.linkedin.com")
# Out:
# C:\Users\asd_v\AppData\Local\Temp\ipykernel_21288\1989233343.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=chromepath)

# %%
from getpass import getpass

# %%
email = 'abdelrhman.mohey96@gmail.com'
password = 'lordasdwithme4ever'
driver.find_element_by_id('username').send_keys(email)
driver.find_element_by_id('password').send_keys(password)
# driver.find_element_by_class_name("btn__primary--large from__button--floating")
driver.find_element_by_css_selector('button[class = "btn__primary--large from__button--floating"]').click()
# Out:
# Enter the Email: ········
# Enter the password: ········
# C:\Users\asd_v\AppData\Local\Temp\ipykernel_21288\2678779284.py:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id('email-or-phone').send_keys(email)
# C:\Users\asd_v\AppData\Local\Temp\ipykernel_21288\2678779284.py:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id('password').send_keys(password)

# %%
# Out:
# C:\Users\asd_v\AppData\Local\Temp\ipykernel_21288\2725414560.py:1: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   driver.find_element_by_css_selector('button[class = "btn__primary--large from__button--floating"]').click()

# %%
['python','c#','webscraping']

# %%
# Out:
# C:\Users\asd_v\AppData\Local\Temp\ipykernel_21288\484485272.py:2: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   search = driver.find_element_by_css_selector('input[class = "search-bar-input"]')

# %%
driver.get("https://wuzzuf.net/jobs/egypt")
searhckey = 'python'
search = driver.find_element(By.CSS_SELECTOR, 'input[class = "search-bar-input"]')
search.clear()
search.send_keys(searhckey)
search.send_keys(Keys.ENTER)
# jobs in page 
in_search = driver.find_element(By.CSS_SELECTOR, 'li[class="css-8neukt"]').text.split(' ')
pages_count = round(int(in_search[-1])/int(in_search[3]))

# %%
#app > div > div.css-1omce3u > div > div > div.css-if9uys > ul > li:nth-child(8) > button
#app > div > div.css-1omce3u > div > div > div.css-if9uys > ul > li:nth-child(2) > button
titles =  []
links = []
companies = []
jobs_tags = []
locations = []
ages = []
Experience = []
for page in range(pages_count):
    #get all jobs
    #//*[@id="app"]/div/div[4]/div/div/div[2]/div[1]/div
    page = driver.find_elements(by=By.CSS_SELECTOR, value='div[class="css-1gatmva e1v1l3u10"]')
    for job in page:
        #title
        titles.append(job.find_element(by=By.CSS_SELECTOR, value='a[class="css-o171kl"]').text)
        
        #link 
        links.append(job.find_element(by=By.CSS_SELECTOR, value='a[class="css-o171kl"]').get_attribute('href').split("?")[0])
        
        #provider
        companies.append(job.find_element(by=By.CSS_SELECTOR, value='a[class="css-17s97q8"]').text.split(' -')[0])
        
        #location
        locations.append(job.find_element(by=By.CSS_SELECTOR, value='span[class="css-5wys0k"]').text)
        
        #age of upload 
        try:
            ages.append(job.find_element(by=By.CSS_SELECTOR, value='div[class="css-4c4ojb"]').text)
        except:
            ages.append(job.find_element(by=By.CSS_SELECTOR, value='div[class="css-do6t5g"]').text)
        
        #experience 
        try:
            Experience.append(
                job.find_element(
                    by=By.CSS_SELECTOR, value='div[class="css-y4udm8"]').find_element(
                    by=By.XPATH, value='.//div[2]/span').text)
        except:
            Experience.append("NOT EXIST")
        
        
        
        
        tags = job.find_elements(by=By.CSS_SELECTOR, value='span[class="css-1ve4b75 eoyjyou0"]')
        job_tags = []
        for tag in tags:
            job_tags.append(tag.text)
        jobs_tags.append(str(job_tags))
        
    driver.find_elements(By.CSS_SELECTOR,'li[class="css-1q4vxyr"]')[-1].click()
    time.sleep(2)

# %%
len(titles)
# Out:
# 177

# %%
titles
# Out:
# ['Senior Python Developer',
#  'Python Backend Developer',
#  'Senior Software Engineer - Python',
#  'Python Back-End Developer (Part-Time)',
#  'Python Developer',
#  'Flask Python Backend Developer.',
#  'Senior Backend Developer (Python/Django)',
#  'Backend Developer (Python/Ruby)',
#  'Senior Python Linux Engineer',
#  'Senior Python Developer',
#  'Software Engineer - Backend Development (Python)',
#  'Python Developer',
#  'Software QA/Automation Engineer [Python]',
#  'Python Developer',
#  'Senior Quality Automation Engineer [Python]',
#  'Senior Backend (Python) Engineer - Customer Domain',
#  'Python Developer - Focused on Cloud Automation',
#  'Senior Python Engineer',
#  'Machine Learning Engineer',
#  'Data Analyst',
#  'Senior Odoo Developer',
#  'Senior Software Engineer (BackEnd)',
#  'Senior Full Stack Developer',
#  'Software Team Leader - Java',
#  'Web Application Intern',
#  'Linux Systems Admin / Engineer',
#  'Senior Back End Developer',
#  'Data Analyst',
# ...

# %%
/html/body/div[1]/div/div[4]/div/div/div[2]/div[3]/div/div[2]
/html/body/div[1]/div/div[4]/div/div/div[2]/div[3]/div/div[2]/div[2]
/html/body/div[1]/div/div[4]/div/div/div[2]/div[2]/div/div[2]/div[2]/span
# Out:
# C:\Users\asd_v\AppData\Local\Temp\ipykernel_21288\2419622624.py:1: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   job.find_element(by=By.CSS_SELECTOR, value='div[class="css-y4udm8"]').find_element_by_class_name('span')
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [225], in <cell line: 1>()
# ----> 1 job.find_element(by=By.CSS_SELECTOR, value='div[class="css-y4udm8"]').find_element_by_class_name('span')
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:473, in WebElement.find_element_by_class_name(self, name)
#     454 """Finds element within this element's children by class name.
#     455
#     456 :Args:
#    (...)
#     468         element = element.find_element_by_class_name('foo')
#     469 """
# ...

# %%
job = driver.find_elements(by=By.CSS_SELECTOR, value='div[class="css-1gatmva e1v1l3u10"]')[1]

# %% [markdown]
# تعلم بايثون

# %% [markdown]
# tech with tem

# %% [markdown]
# search with
# >
#     id
#     class
#     tagname

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support import expected_conditions as EC

# %%
driver = webdriver.Chrome(executable_path="chromedriver.exe")
driver.get("https://techwithtim.net/")
search = driver.find_element_by_name("s")
search.send_keys("test")
search.send_keys(Keys.RETURN)
# print(driver.page_source)
try:
    main = WebDriverWait(driver, timeout=3).until(lambda d: d.find_element_by_id("main"))
#     print(main.text)
    articles = main.find_elements_by_tag_name("article")
    for article in articles:
        header = article.find_element_by_class_name("entry-summary")
        print(header.text)
    
except:
    driver.quit()
# main = 

# time.sleep(5)
# driver.quit()
# Out:
# HTTP MethodsIn this tutorial we will talk about HTTP methods. HTTP methods are the standard way of sending information to and from a web server. To break it down, a website runs on a server or multiple servers and simple returns information to a client (web-browser). Information is exchanged between the client and the server […]
# Creating a Base Template So you may have realized that creating new web pages for every single page on our website is extremely inefficient. Especially when our website follows a theme and has similar elements (like a sidebar) on every page. This is where template inheritance comes in. We will talk about how to inherit […]
# Redirecting ContinuedStarting from where we left off in the last tutorial. I wanted to show how to redirect to a function that takes an argument (like our user function). To do this we simply need to define the parameter name and a value in the url_for function, like below.from flask import Flask, redirect, url_for app […]
# ...

# %%
driver = webdriver.Chrome(executable_path="chromedriver.exe")
driver.get("https://techwithtim.net/")
link = driver.find_element_by_partial_link_text("Python Programming")
time.sleep(2)
link.click()

# try:
element = WebDriverWait(driver,10).until(
    EC.presence_of_elemen_located((By.LINK_TEXT, "Beginner Python Tutorials"))
)
element.click()
# except:
#     time.sleep(5)
#     driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
driver = webdriver.Chrome(executable_path="chromedriver.exe")
driver.get("https://orteil.dashnet.org/cookieclicker/")

driver.implicitly_wait(5)

cookie = driver.find_element_by_id("bigCookie")
cookie_count = driver.find_element_by_id("cookies")
ithems = [driver.find_element_by_id("productPrice" + str(i)) for i in range(1,-1,-1) ]

    
actions = ActionChains(driver)

actions.click(cookie)
for i in range(5000):
    actions.perform()
    count = int(cookie_count.text.split(" ")[0])
    for item in ithems:
        value = int(item.text)
        if value <= count:
            upgrade = ActionChains(driver)
            upgrade.move_to_element(item)
            upgrade.click()
            upgrade.perform()
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6044/2374308592.py in <module>
#      16 for i in range(5000):
#      17     actions.perform()
# ---> 18     count = int(cookie_count.text.split(" ")[0])
#      19     for item in ithems:
#      20         value = int(item.text)
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in text(self)
#      74     def text(self):
#      75         """The text of the element."""
# ---> 76         return self._execute(Command.GET_ELEMENT_TEXT)['value']
#      77
#      78     def click(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
# ...
